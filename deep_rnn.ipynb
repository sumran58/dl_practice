# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Dense,SimpleRNN,Input

# %%
(X_train,y_train),(X_test,y_test)=imdb.load_data(num_words=10000)
X_train=pad_sequences(X_train,maxlen=100)
X_test=pad_sequences(X_test,maxlen=100)

# %%
model = Sequential([
    Input(shape=(100,)),
    Embedding(input_dim=10000, output_dim=32),
    SimpleRNN(5, return_sequences=True),
    SimpleRNN(5),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 100, 32)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_4 (SimpleRNN)        │ (None, 100, 5)         │           190 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_5 (SimpleRNN)        │ (None, 5)              │            55 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 320,251 (1.22 MB)
#  Trainable params: 320,251 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(X_train,y_train,epochs=5,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 31s 45ms/step - accuracy: 0.5482 - loss: 0.6856 - val_accuracy: 0.5754 - val_loss: 0.6699
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 28s 45ms/step - accuracy: 0.7294 - loss: 0.5498 - val_accuracy: 0.7508 - val_loss: 0.5327
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.8488 - loss: 0.3624 - val_accuracy: 0.7586 - val_loss: 0.5363
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9114 - loss: 0.2406 - val_accuracy: 0.7464 - val_loss: 0.5946
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9458 - loss: 0.1640 - val_accuracy: 0.7642 - val_loss: 0.6219
